# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Lab-|-Matplotlib-&amp;-Seaborn" data-toc-modified-id="Lab-|-Matplotlib-&amp;-Seaborn-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Lab | Matplotlib &amp; Seaborn</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Import-all-the-libraries-that-are-necessary." data-toc-modified-id="Import-all-the-libraries-that-are-necessary.-1.0.0.1"><span class="toc-item-num">1.0.0.1&nbsp;&nbsp;</span>Import all the libraries that are necessary.</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Challenge-1" data-toc-modified-id="Challenge-1-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Challenge 1</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Data" data-toc-modified-id="Data-2.0.0.1"><span class="toc-item-num">2.0.0.1&nbsp;&nbsp;</span>Data</a></span></li><li><span><a href="#Plot-(x,y)-and-(x,z)-on-the-axes." data-toc-modified-id="Plot-(x,y)-and-(x,z)-on-the-axes.-2.0.0.2"><span class="toc-item-num">2.0.0.2&nbsp;&nbsp;</span>Plot (x,y) and (x,z) on the axes.</a></span></li><li><span><a href="#Use-plt.subplots(nrows=1,-ncols=2)-to-create-the-plot-below" data-toc-modified-id="Use-plt.subplots(nrows=1,-ncols=2)-to-create-the-plot-below-2.0.0.3"><span class="toc-item-num">2.0.0.3&nbsp;&nbsp;</span>Use plt.subplots(nrows=1, ncols=2) to create the plot below</a></span></li><li><span><a href="#Augmenting-your-previous-code,-resize-your-previous-plot." data-toc-modified-id="Augmenting-your-previous-code,-resize-your-previous-plot.-2.0.0.4"><span class="toc-item-num">2.0.0.4&nbsp;&nbsp;</span>Augmenting your previous code, resize your previous plot.</a></span></li><li><span><a href="#Plot-both-y=x^2-and-y=exp(x)-in-the-same-plot-using-normal-and-logarithmic-scale." data-toc-modified-id="Plot-both-y=x^2-and-y=exp(x)-in-the-same-plot-using-normal-and-logarithmic-scale.-2.0.0.5"><span class="toc-item-num">2.0.0.5&nbsp;&nbsp;</span>Plot both y=x^2 and y=exp(x) in the same plot using normal and logarithmic scale.</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Challenge-2" data-toc-modified-id="Challenge-2-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Challenge 2</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Import-the-Fitbit2.csv-file-and-name-your-dataset-fitbit." data-toc-modified-id="Import-the-Fitbit2.csv-file-and-name-your-dataset-fitbit.-3.0.0.1"><span class="toc-item-num">3.0.0.1&nbsp;&nbsp;</span>Import the Fitbit2.csv file and name your dataset fitbit.</a></span></li><li><span><a href="#From-the-Fitbit-data,-we-want-to-visually-understand:" data-toc-modified-id="From-the-Fitbit-data,-we-want-to-visually-understand:-3.0.0.2"><span class="toc-item-num">3.0.0.2&nbsp;&nbsp;</span>From the Fitbit data, we want to visually understand:</a></span></li><li><span><a href="#Write-a-loop-to-plot-3-scatter-plots-of-the-following-features:" data-toc-modified-id="Write-a-loop-to-plot-3-scatter-plots-of-the-following-features:-3.0.0.3"><span class="toc-item-num">3.0.0.3&nbsp;&nbsp;</span>Write a loop to plot 3 scatter plots of the following features:</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Challenge-3" data-toc-modified-id="Challenge-3-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Challenge 3</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Open-the-titanic-file.-Name-your-dataset-titanic." data-toc-modified-id="Open-the-titanic-file.-Name-your-dataset-titanic.-4.0.0.1"><span class="toc-item-num">4.0.0.1&nbsp;&nbsp;</span>Open the titanic file. Name your dataset titanic.</a></span></li><li><span><a href="#Explore-the-titanic-dataset-using-Pandas-dtypes." data-toc-modified-id="Explore-the-titanic-dataset-using-Pandas-dtypes.-4.0.0.2"><span class="toc-item-num">4.0.0.2&nbsp;&nbsp;</span>Explore the titanic dataset using Pandas dtypes.</a></span></li><li><span><a href="#What-are-your-numerical-variables?-What-are-your-categorical-variables?" data-toc-modified-id="What-are-your-numerical-variables?-What-are-your-categorical-variables?-4.0.0.3"><span class="toc-item-num">4.0.0.3&nbsp;&nbsp;</span>What are your numerical variables? What are your categorical variables?</a></span></li><li><span><a href="#Set-the-plot-style-to-classic-and-the-figure-size-to-(12,6)." data-toc-modified-id="Set-the-plot-style-to-classic-and-the-figure-size-to-(12,6).-4.0.0.4"><span class="toc-item-num">4.0.0.4&nbsp;&nbsp;</span>Set the plot style to classic and the figure size to (12,6).</a></span></li><li><span><a href="#Use-the-right-visulalization-to-show-the-distribution-of-the-column-Age." data-toc-modified-id="Use-the-right-visulalization-to-show-the-distribution-of-the-column-Age.-4.0.0.5"><span class="toc-item-num">4.0.0.5&nbsp;&nbsp;</span>Use the right visulalization to show the distribution of the column Age.</a></span></li><li><span><a href="#Use-subplots-and-plot-the-distribution-of-the-Age-variable-with-bins-equal-to-10,-20-and-50." data-toc-modified-id="Use-subplots-and-plot-the-distribution-of-the-Age-variable-with-bins-equal-to-10,-20-and-50.-4.0.0.6"><span class="toc-item-num">4.0.0.6&nbsp;&nbsp;</span>Use subplots and plot the distribution of the Age variable with bins equal to 10, 20 and 50.</a></span></li><li><span><a href="#How-does-the-bin-size-affect-your-plot?-Comment." data-toc-modified-id="How-does-the-bin-size-affect-your-plot?-Comment.-4.0.0.7"><span class="toc-item-num">4.0.0.7&nbsp;&nbsp;</span>How does the bin size affect your plot? Comment.</a></span></li><li><span><a href="#Use-seaborn-to-show-the-distribution-of-the-column-Age." data-toc-modified-id="Use-seaborn-to-show-the-distribution-of-the-column-Age.-4.0.0.8"><span class="toc-item-num">4.0.0.8&nbsp;&nbsp;</span>Use seaborn to show the distribution of the column Age.</a></span></li><li><span><a href="#Use-the-right-plot-to-visualize-the-column-Gender.-There-are-2-ways-of-doing-it.-Do-it-both-ways." data-toc-modified-id="Use-the-right-plot-to-visualize-the-column-Gender.-There-are-2-ways-of-doing-it.-Do-it-both-ways.-4.0.0.9"><span class="toc-item-num">4.0.0.9&nbsp;&nbsp;</span>Use the right plot to visualize the column Gender. There are 2 ways of doing it. Do it both ways.</a></span></li><li><span><a href="#Use-the-right-plot-to-visualize-the-column-Pclass." data-toc-modified-id="Use-the-right-plot-to-visualize-the-column-Pclass.-4.0.0.10"><span class="toc-item-num">4.0.0.10&nbsp;&nbsp;</span>Use the right plot to visualize the column Pclass.</a></span></li><li><span><a href="#We-would-like-to-have-in-one-single-plot-the-summary-statistics-of-the-feature-Age.-What-kind-of-plot-would-you-use?" data-toc-modified-id="We-would-like-to-have-in-one-single-plot-the-summary-statistics-of-the-feature-Age.-What-kind-of-plot-would-you-use?-4.0.0.11"><span class="toc-item-num">4.0.0.11&nbsp;&nbsp;</span>We would like to have in one single plot the summary statistics of the feature Age. What kind of plot would you use?</a></span></li><li><span><a href="#What-does-the-last-plot-tells-you-about-the-feature-Age?-Comment." data-toc-modified-id="What-does-the-last-plot-tells-you-about-the-feature-Age?-Comment.-4.0.0.12"><span class="toc-item-num">4.0.0.12&nbsp;&nbsp;</span>What does the last plot tells you about the feature Age? Comment.</a></span></li><li><span><a href="#Now-in-addition-to-the-summary-statistics,-we-want-to-have-in-the-SAME-plot-the-distribution-of-Age.-What-kind-of-plot-would-you-use?" data-toc-modified-id="Now-in-addition-to-the-summary-statistics,-we-want-to-have-in-the-SAME-plot-the-distribution-of-Age.-What-kind-of-plot-would-you-use?-4.0.0.13"><span class="toc-item-num">4.0.0.13&nbsp;&nbsp;</span>Now in addition to the summary statistics, we want to have in the SAME plot the distribution of Age. What kind of plot would you use?</a></span></li><li><span><a href="#What-additional-information-the-last-plot-provides-you-about-the-feature-Age?-Comment." data-toc-modified-id="What-additional-information-the-last-plot-provides-you-about-the-feature-Age?-Comment.-4.0.0.14"><span class="toc-item-num">4.0.0.14&nbsp;&nbsp;</span>What additional information the last plot provides you about the feature Age? Comment.</a></span></li><li><span><a href="#We-suspect-that-there-is-a-linear-relationship-between-Fare-and-Age.-Use-the-right-plot-to-show-the-relationship-between-these-2-features.-There-are-2-ways,-please-do-it-both-ways." data-toc-modified-id="We-suspect-that-there-is-a-linear-relationship-between-Fare-and-Age.-Use-the-right-plot-to-show-the-relationship-between-these-2-features.-There-are-2-ways,-please-do-it-both-ways.-4.0.0.15"><span class="toc-item-num">4.0.0.15&nbsp;&nbsp;</span>We suspect that there is a linear relationship between Fare and Age. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.</a></span></li><li><span><a href="#Using-Seaborn-plot-the-correlation-matrix." data-toc-modified-id="Using-Seaborn-plot-the-correlation-matrix.-4.0.0.16"><span class="toc-item-num">4.0.0.16&nbsp;&nbsp;</span>Using Seaborn plot the correlation matrix.</a></span></li><li><span><a href="#What-are-the-most-correlated-features?-Comment." data-toc-modified-id="What-are-the-most-correlated-features?-Comment.-4.0.0.17"><span class="toc-item-num">4.0.0.17&nbsp;&nbsp;</span>What are the most correlated features? Comment.</a></span></li><li><span><a href="#Use-the-right-plot-to-display-the-summary-statistics-of-the-Age-in-function-of-the-Pclass." data-toc-modified-id="Use-the-right-plot-to-display-the-summary-statistics-of-the-Age-in-function-of-the-Pclass.-4.0.0.18"><span class="toc-item-num">4.0.0.18&nbsp;&nbsp;</span>Use the right plot to display the summary statistics of the Age in function of the Pclass.</a></span></li><li><span><a href="#Use-the-seaborn-to-plot-the-distribution-of-the-Age-based-on-the-Gender." data-toc-modified-id="Use-the-seaborn-to-plot-the-distribution-of-the-Age-based-on-the-Gender.-4.0.0.19"><span class="toc-item-num">4.0.0.19&nbsp;&nbsp;</span>Use the seaborn to plot the distribution of the Age based on the Gender.</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Lab | Matplotlib & Seaborn

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Data

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
# There are 2 ways of doing this. Do in both ways.
# Hint: Check out the nrows, ncols, and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# OPTION 1
# Create a figure of a fixed size
plt.figure(figsize=(15,6))

# First plot
plt.subplot(1,2,1)
plt.plot(x, y, lw=3, color="b", ls='--')

# Second plot
plt.subplot(1,2,2)
plt.plot(x, z, lw=3, color="r", ls='-')

# Show the plot
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot below

# %%
# OPTION 2

# Create a figure of a fixed size and axes
f, ax = plt.subplots(1,2)
f.set_figwidth(15)
f.set_figheight(6)

# Plots
ax[0].plot(x, y, color="b", lw=3, ls='--')
ax[1].plot(x, z, color="r", lw=3, ls='-')

# Show the plot
plt.show()

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
# Hint: Add the figsize argument in plt.subplots()

# %%
# ENHANCED VERSION to see more matplotlib features

# Variables
fs = 16 # fontsize
fw = 700 # fontweight
lw = 3 # lineweight
y_rot = 0 # ylabel rotation

# Create a figure of a fixed size and axes
f, ax = plt.subplots(1,2, figsize=(12,4))

# First plot adding a title and x and y labels
ax[0].plot(x, y, color="b", lw=lw, ls='--')
ax[0].set_xlabel('x', fontsize = fs)
ax[0].set_ylabel('y', rotation = y_rot, fontsize = fs)
ax[0].set_title('x*2', fontweight = fw)

# Second plot adding a title and x and y labels
ax[1].plot(x, z, color="r", lw=lw, ls='-')
ax[1].set_xlabel('x', fontsize = fs)
ax[1].set_ylabel('z', rotation = y_rot, fontsize = fs)
ax[1].set_title('x**2', fontweight = fw)

# Show the plot
plt.show()

# %% [markdown]
# #### Plot both y=x^2 and y=exp(x) in the same plot using normal and logarithmic scale.
# Hint: Use set_xscale and set_yscale

# %%
# Create a figure of a fixed size and axes
f, ax = plt.subplots(1, 2, figsize=(10,4))

# Normal plot
ax[0].plot(x, x**2, 'r', x, np.exp(x), 'g')
ax[0].set_title("Normal scale")

# Logarithmic scale
ax[1].plot(x, x**2, 'r', x, np.exp(x), 'g')
ax[1].set_yscale("log")
ax[1].set_title("Logarithmic scale (y)")

# Show plot
plt.show()

# %%
# ALTERNATIVE WITH LEGEND

# Create a figure of a fixed size and axes
f, ax = plt.subplots(1, 2, figsize=(10,4))

# Normal plot
ax[0].plot(x, x**2, 'r', label = 'x**2')
ax[0].plot(x, np.exp(x), 'g', label = 'exp(x)')
ax[0].set_title("Normal scale")
ax[0].legend()

# Logarithmic scale
ax[1].plot(x, x**2, 'r', label = 'x**2')
ax[1].plot(x, np.exp(x), 'g', label = 'exp(x)')
ax[1].set_yscale("log")
ax[1].set_title("Logarithmic scale (y)")
ax[1].legend()

# Show plot
plt.show()

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Import the Fitbit2.csv file and name your dataset fitbit.

# %%
# Read the data
fitbit = pd.read_csv('data/Fitbit2.csv')
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month.
# Is Fitbitter more active on weekend or workdays?
# All plots must be in the same jupyter notebook cell.
#
# Hints:
#
# - Use Months_encoded and Week_or Weekend columns.
# - Use matplolib.pyplot object oriented API.
# - Set your size figure to 12,4
# - Explore plt.sca
# - Explore plt.xticks
# - Save your figures

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# Find the median steps for each month
weekday_steps = fitbit['Steps'].groupby(fitbit['Months_encoded']).median()

# Create a figure of a fixed size and axes
f, ax = plt.subplots(1,2, figsize = (12,4))

# Set the current axes instance to ax[0] - Now plt methods will affect ax[0]
plt.sca(ax[0])

# Plot the weekday steps in the current axes
weekday_steps.plot(kind = 'line',linewidth=2)

# Add labels, title, etc
plt.ylabel('Median number of steps')
plt.xlabel('Months')
plt.title('Median Steps walked by month')
plt.xticks(range(13), ['','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])

# Save the figure
plt.savefig('figures/steps_months.png',bbox_inches='tight')

# MEDIAN STEPS BY WORK_OR_WEEKEND
# Set the current axes instance to ax[1] - Now plt methods will affect ax[1]
plt.sca(ax[1])

# Find the median steps for workdays and weekdays
weekday_steps = fitbit['Steps'].groupby(fitbit['Work_or_Weekend']).median().sort_values()

# Plot the workday and weekend steps in the current axes
weekday_steps.plot(kind = 'bar', alpha = 0.5)

# Add labels, title, etc
plt.ylabel('Median number of steps')
plt.title('Median Steps walked by Workdays and Weekend')
plt.xticks(range(2), ['Weekend','Workdays'], rotation = 0)

# Save the figure
plt.savefig('figures/steps_work_weekend.png', bbox_inches='tight')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# Minutes Lightly Active vs Steps
# Minutes Very Active vs Steps
# Minutes Sedentary vs Steps

# %%
# ALTERNATIVE 1
# Create a df with the columns we are interested in 
cols = ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary','Steps']
df = fitbit[cols]

# Create a figure of a fixed size and axes
f, ax = plt.subplots(1, 3, figsize = (20,8))

# Iterate to draw each scatter plot
for i in range(3):
    plt.sca(ax[i])
    plt.scatter(df[cols[i]], df[cols[3]], color = 'darkblue')
    plt.xlabel(df[cols[i]].name)
    plt.ylabel('Steps')

# %%
# ALTERNATIVE 2
# Create a df with the columns we are interested in 
cols = ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary','Steps']
df = fitbit[cols]

# Create a figure of a fixed size and axes
f, ax = plt.subplots(1, 3, figsize = (20,8))

# Iterate to draw each scatter plot
for i in range(3):
    ax[i].scatter(df[cols[i]], df[cols[3]], color = 'darkblue')
    ax[i].set_xlabel(df[cols[i]].name)
    ax[i].set_ylabel('Steps')

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the titanic file. Name your dataset titanic.

# %%
# Read the data
titanic = pd.read_csv('data/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# Hint: Use Pandas select_dtypes

# %%
# Numerical variables
titanic.select_dtypes(exclude=object).dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# dtype: object

# %%
# Categorical variables
titanic.select_dtypes(exclude=['int','float']).dtypes
# Out:
# Name        object
# Gender      object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# Hint: To set the style you can use matplotlib.pyplot functions or seaborn

# %%
# Plot style change
plt.style.use('classic')   # matplotlib
sns.set_style('whitegrid') # seaborn

# Figure size change
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of the column Age.

# %%
# Pandas plots are based on matplotlib

# Plot the histogram of column Age
titanic['Age'].hist(bins=50)

# Set titles, labels, etc
plt.title('Distribution of age')
plt.xlabel('Age')
plt.ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the Age variable with bins equal to 10, 20 and 50.

# %%
# Variables
bins = [10, 20, 50]

# Create a figure of a fixed size and axes
f, ax = plt.subplots(1,3)
f.set_figwidth(15)

# Plot the histogram using a different number of bins
for i in range(3):
    plt.sca(ax[i])
    titanic['Age'].hist(bins=bins[i])
    plt.title('n =' + str(bins[i]))
    plt.xlabel('Age')
    plt.ylabel('Count')

# %% [markdown]
# #### How does the bin size affect your plot? Comment.

# %% [markdown]
# ~~~~
# Using a low number of bins (wider bins) reduces noise on the distribution estimation while using a
# high number of bins (narrower bins) gives greater precision to the distribution estimation (and more noise).
# ~~~~

# %% [markdown]
# #### Use seaborn to show the distribution of the column Age.

# %%
# Seaborn is a Python library based on matplotlib

# Plot of the age histogram using seaborn
sns.distplot(titanic['Age'], bins = 30, kde = False, color = 'red')

# Show the plot
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column Gender. There are 2 ways of doing it. Do it both ways.
# Hint: Use matplotlib and seaborn

# %%
# OPTION 1 - Matplotlib

# Bar plot of the gender
titanic['Gender'].value_counts().plot(kind='bar')

# Add labels to the plot and change xticks rotation
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation = 0)

# Show the plot
plt.show()

# %%
# OPTION 2 - Seaborn

# Seaborn Countplot
sns.countplot(x ='Gender', data = titanic)

# Show the plot
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column Pclass.

# %%
# Bar plot of Pclass
titanic['Pclass'].value_counts().plot(kind='bar')

# Add labels to the plot and change xticks rotation
plt.xlabel('Class')
plt.ylabel('Count')
plt.xticks(rotation = 0)

# Show the plot
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature Age. What kind of plot would you use?

# %%
# Box plot
titanic.boxplot(column='Age')

# Show the plot
plt.show()

# %% [markdown]
# #### What does the last plot tells you about the feature Age? Comment.

# %% [markdown]
# ~~~~
# The statistics that you can get from the boxplot are the minimum, first quartile, median,
# third quartile, and maximum.
#
# The red line shows us the median of Age.
# The blue box shows us the interquartile range (from Q1 to Q3).
# It also shows us the outliers, which are out of the maximum and minimum range (Q1 - 1.5*IQR, Q3 + 1.5*IQR).
# ~~~~

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the SAME plot the distribution of Age. What kind of plot would you use?

# %%
# Set figure size
plt.figure(figsize = (15,8))

# Violin plot
sns.violinplot("Age", data = titanic)

# Show the plot
plt.show()

# %% [markdown]
# #### What additional information the last plot provides you about the feature Age? Comment.

# %% [markdown]
# ~~~~
# This plot is a combination of a boxplot and a density plot. The violin plot features a kernel density estimation
# of the underlying distribution of the data.
#
# The black central part of the plot is the same as a boxplot and the white dot is the median.
# The blue part is the distribution of the data.
# ~~~~

# %% [markdown]
# #### We suspect that there is a linear relationship between Fare and Age. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# Hint: One of the ways involves using Seaborn.

# %%
# OPTION 1

# Scatter plot
plt.scatter(titanic['Fare'], titanic['Age'])

# Add labels
plt.xlabel('Fare')
plt.ylabel('Age')

# Show the plot
plt.show()

# %%
# OPTION 2

# Joinplot
sns.jointplot(x = 'Fare', y = 'Age', data = titanic)

# Show the plot
plt.show()

# %% [markdown]
# #### Using Seaborn plot the correlation matrix.

# %%
# Set figure size
plt.figure(figsize = (10,8))

# Correlation matrix
sns.heatmap(titanic.corr(), cmap='coolwarm')

# Add title
plt.title('Correlation matrix')

# Show plot
plt.show()

# %% [markdown]
# #### What are the most correlated features? Comment.

# %% [markdown]
# ~~~~~
# The most correlated features are Parch and SibSp.
# ~~~~~

# %% [markdown]
# #### Use the right plot to display the summary statistics of the Age in function of the Pclass.

# %%
# Boxplot
sns.boxplot(x='Pclass',y='Age',data=titanic,palette='rainbow')

# Show the plot
plt.show()

# %% [markdown]
# #### Use the seaborn to plot the distribution of the Age based on the Gender.
# Hint: Use Facetgrid

# %%
# Create a grid with FacetGrid
g = sns.FacetGrid(data = titanic, col = 'Gender')

# Draw a plot on each facet
g.map(plt.hist, 'Age')

# Show the plot
plt.show()
