# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Paste the url you obtained for your data
url='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=84&sort=sale'

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions). Hint: use the headers parameter to get the data!

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}

# %%
# Your code

response = requests.get(url,headers=headers)
results = response.json()
results


flattened_data = json_normalize(results)

flattened_data1 = json_normalize(flattened_data.articles[0])

# %%
flattened_data1
# Out:
#               sku                                               name  \
# 0   LE223A054-Q12        710 SUPER SKINNY - Jeans Skinny - meteorite
# 1   QU124L020-Q11      BICHENO BLOOM YOUTH - Veste mi-saison - black
# 2   NI126K00N-K11  HOODIE CLUB - veste en sweat zippée - midnight...
# 3   GP024L03G-K11                BABY - Veste d'hiver - bristol blue
# 4   NI114D0C1-A12  AIR MAX TAILWIND - Baskets basses - white/race...
# ..            ...                                                ...
# 79  NL623J011-Q11                CREW NECK JUMPER - Pullover - black
# 80  BL824L01X-C11                         Veste d'hiver - mittelgrau
# 81  LE223K01R-Q11   CROPPED BRANDED HOODIE - Sweat à capuche - black
# 82  AD123B021-Q11                            TAPE  - Legging - black
# 83  RI923D05O-N11                SET - veste en sweat zippée - khaki
#
#                                                 sizes  \
# 0                [3a, 4a, 6a, 8a, 10a, 12a, 14a, 16a]
# 1                             [8a, 9a, 12a, 14a, 16a]
# 2                   [6-7a, 8-9a, 10-11a, 12-13a, 14a]
# 3                               [0-6m, 6-12m, 12-18m]
# 4                [35.5, 36.5, 37.5, 38, 38.5, 39, 40]
# ..                                                ...
# 79                       [9a, 10-11a, 12-13a, 14-15a]
# 80                       [2a, 3a, 4a, 5a, 6a, 7a, 8a]
# 81                                [8a, 10a, 12a, 14a]
# 82  [7-8a, 8-9a, 9-10a, 10-11a, 11-12a, 12-13a, 13...
# 83                        [5-6a, 7-8a, 9-10a, 11-12a]
#
#                                               url_key  \
# 0   levisr-710-super-skinny-jeans-skinny-le223a054...
# 1   quiksilver-bicheno-bloom-youth-veste-dhiver-bl...
# 2   nike-sportswear-hoodie-club-veste-en-sweat-zip...
# 3    gap-baby-veste-dhiver-bristol-blue-gp024l03g-k11
# 4   nike-sportswear-air-max-tailwind-baskets-basse...
# ..                                                ...
# 79  new-look-915-generation-crew-neck-jumper-pullo...
# 80   blue-seven-veste-dhiver-mittelgrau-bl824l01x-c11
# 81  levisr-cropped-branded-hoodie-sweatshirt-black...
# 82  adidas-originals-tape-legging-black-ad123b021-q11
# 83  river-island-set-pantalon-de-survetement-khaki...
#
#                                                 media  \
# 0   [{'path': 'LE/22/3A/05/4Q/12/LE223A054-Q12@4.j...
# 1   [{'path': 'QU/12/4L/02/0Q/11/QU124L020-Q11@8.j...
# 2   [{'path': 'NI/12/6K/00/NK/11/NI126K00N-K11@7.j...
# 3   [{'path': 'GP/02/4L/03/GK/11/GP024L03G-K11@8.j...
# 4   [{'path': 'NI/11/4D/0C/1A/12/NI114D0C1-A12@3.j...
# ..                                                ...
# 79  [{'path': 'NL/62/3J/01/1Q/11/NL623J011-Q11@10....
# 80  [{'path': 'BL/82/4L/01/XC/11/BL824L01X-C11@13....
# 81  [{'path': 'LE/22/3K/01/RQ/11/LE223K01R-Q11@4.j...
# 82  [{'path': 'AD/12/3B/02/1Q/11/AD123B021-Q11@2.j...
# 83  [{'path': 'RI/92/3D/05/ON/11/RI923D05O-N11@5.j...
#
#                  brand_name  is_premium  \
# 0                   Levi's®       False
# 1                Quiksilver       False
# 2           Nike Sportswear       False
# 3                       GAP       False
# 4           Nike Sportswear       False
# ..                      ...         ...
# 79  New Look 915 Generation       False
# 80               Blue Seven       False
# 81                  Levi's®       False
# 82         adidas Originals       False
# 83             River Island       False
#
#                                       family_articles  \
# 0   [{'sku': 'LE223A054-Q12', 'url_key': 'levisr-7...
# 1   [{'sku': 'QU124L020-Q11', 'url_key': 'quiksilv...
# 2   [{'sku': 'NI126K00N-K11', 'url_key': 'nike-spo...
# 3   [{'sku': 'GP024L03G-K11', 'url_key': 'gap-baby...
# 4   [{'sku': 'NI114D0C1-A12', 'url_key': 'nike-spo...
# ..                                                ...
# 79  [{'sku': 'NL623J011-Q11', 'url_key': 'new-look...
# 80  [{'sku': 'BL824L01X-C11', 'url_key': 'blue-sev...
# 81  [{'sku': 'LE223K01R-Q11', 'url_key': 'levisr-c...
# 82  [{'sku': 'AD123B021-Q11', 'url_key': 'adidas-o...
# 83  [{'sku': 'RI923D05O-N11', 'url_key': 'river-is...
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 1   [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 2   [{'key': 'discountRate', 'value': 'Jusqu’à -30...      clothing
# 3   [{'key': 'discountRate', 'value': '-35%', 'tra...      clothing
# 4   [{'key': 'discountRate', 'value': '-25%', 'tra...          shoe
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': '-15%', 'tra...      clothing
# 80  [{'key': 'discountRate', 'value': '-60%', 'tra...      clothing
# 81  [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 82  [{'key': 'discountRate', 'value': 'Jusqu’à -20...      clothing
# 83  [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
#
#    delivery_promises price.original price.promotional  \
# 0                 []        44,95 €           35,95 €
# 1                 []       129,99 €          103,99 €
# 2                 []        38,95 €           27,25 €
# 3                 []        39,95 €           25,95 €
# 4                 []       134,95 €          100,95 €
# ..               ...            ...               ...
# 79                []         8,95 €            7,59 €
# 80                []        39,95 €           15,95 €
# 81                []        49,95 €           39,95 €
# 82                []        27,95 €           22,35 €
# 83                []        43,95 €           35,20 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                         True                                False
# 1                        False                                False
# 2                         True                                False
# 3                        False                                False
# 4                        False                                False
# ..                         ...                                  ...
# 79                       False                                False
# 80                       False                                False
# 81                       False                                False
# 82                        True                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                     True
# 1                                    False
# 2                                     True
# 3                                    False
# 4                                    False
# ..                                     ...
# 79                                   False
# 80                                   False
# 81                                   False
# 82                                    True
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only amount
# 0                                       False    NaN
# 1                                       False    NaN
# 2                                       False    NaN
# 3                                       False    NaN
# 4                                       False    NaN
# ..                                        ...    ...
# 79                                      False    NaN
# 80                                      False    NaN
# 81                                      False    NaN
# 82                                      False    NaN
# 83                                      False    NaN
#
# [84 rows x 18 columns]

# %% [markdown]
# #### Collect all the objects from selected filters. Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']

# Your code
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={k}&sort=sale'
    response = requests.get(url,headers=headers)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

# %%
df.head()
# Out:
#               amount        brand_name delivery_promises  \
# sku
# NI116D04L-Q11    NaN   Nike Sportswear                []
# NI114D0B9-Q14    NaN   Nike Sportswear                []
# TO113I00G-K11    NaN    Tommy Hilfiger                []
# AD116D007-A11    NaN  adidas Originals                []
# AD126L00J-Q11    NaN  adidas Originals                []
#
#                                                  family_articles  \
# sku
# NI116D04L-Q11  [{'sku': 'NI116D04L-Q11', 'url_key': 'nike-spo...
# NI114D0B9-Q14  [{'sku': 'NI114D0B9-Q14', 'url_key': 'nike-spo...
# TO113I00G-K11  [{'sku': 'TO113I00G-K11', 'url_key': 'tommy-hi...
# AD116D007-A11  [{'sku': 'AD116D007-A11', 'url_key': 'adidas-o...
# AD126L00J-Q11  [{'sku': 'AD126L00J-Q11', 'url_key': 'adidas-o...
#
#                                                            flags  is_premium  \
# sku
# NI116D04L-Q11  [{'key': 'discountRate', 'value': 'Jusqu’à -20...       False
# NI114D0B9-Q14  [{'key': 'discountRate', 'value': '-20%', 'tra...       False
# TO113I00G-K11  [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# AD116D007-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -30...       False
# AD126L00J-Q11  [{'key': 'discountRate', 'value': 'Jusqu’à -35...       False
#
#                                                            media  \
# sku
# NI116D04L-Q11  [{'path': 'NI/11/6D/04/LQ/11/NI116D04L-Q11@8.j...
# NI114D0B9-Q14  [{'path': 'NI/11/4D/0B/9Q/14/NI114D0B9-Q14@9.j...
# TO113I00G-K11  [{'path': 'TO/11/3I/00/GK/11/TO113I00G-K11@8.1...
# AD116D007-A11  [{'path': 'AD/11/6D/00/7A/11/AD116D007-A11@12....
# AD126L00J-Q11  [{'path': 'AD/12/6L/00/JQ/11/AD126L00J-Q11@8.j...
#
#                                                             name  \
# sku
# NI116D04L-Q11  COURT BOROUGH MID BOOT WINTERIZED - Chaussures...
# NI114D0B9-Q14  AIR MAX 200 - Baskets basses - black/metallic ...
# TO113I00G-K11                                    Bottines - blue
# AD116D007-A11                STAN SMITH - Baskets basses - white
# AD126L00J-Q11               JACKET - Veste d'hiver - black/white
#
#               price.base_price  price.has_different_original_prices  ...  \
# sku                                                                  ...
# NI116D04L-Q11              NaN                                False  ...
# NI114D0B9-Q14              NaN                                False  ...
# TO113I00G-K11              NaN                                False  ...
# AD116D007-A11              NaN                                False  ...
# AD126L00J-Q11              NaN                                False  ...
#
#                price.has_different_promotional_prices  \
# sku
# NI116D04L-Q11                                    True
# NI114D0B9-Q14                                   False
# TO113I00G-K11                                    True
# AD116D007-A11                                    True
# AD126L00J-Q11                                    True
#
#                price.has_discount_on_selected_sizes_only  price.original  \
# sku
# NI116D04L-Q11                                      False         54,95 €
# NI114D0B9-Q14                                      False        104,95 €
# TO113I00G-K11                                      False         94,95 €
# AD116D007-A11                                      False         54,95 €
# AD126L00J-Q11                                      False         64,95 €
#
#               price.promotional product_group  \
# sku
# NI116D04L-Q11           43,95 €          shoe
# NI114D0B9-Q14           83,95 €          shoe
# TO113I00G-K11           66,45 €          shoe
# AD116D007-A11           38,45 €          shoe
# AD126L00J-Q11           41,95 €      clothing
#
#                                                            sizes  \
# sku
# NI116D04L-Q11       [28, 28.5, 29.5, 30, 31.5, 32, 33.5, 34, 35]
# NI114D0B9-Q14                   [35.5, 36.5, 37.5, 38, 38.5, 40]
# TO113I00G-K11           [28, 29, 30, 33, 34, 35, 36, 37, 38, 40]
# AD116D007-A11  [28, 29, 30, 31, 32, 33, 34, 35, 28 1/2, 30 1/...
# AD126L00J-Q11                     [3-4a, 4-5a, 5-6a, 6-7a, 7-8a]
#
#                           tracking_information.impression_beacon  \
# sku
# NI116D04L-Q11  https://ccp-et.metrigo.zalan.do/event/sbv?z=98...
# NI114D0B9-Q14  https://ccp-et.metrigo.zalan.do/event/sbv?z=98...
# TO113I00G-K11  https://ccp-et.metrigo.zalan.do/event/sbv?z=98...
# AD116D007-A11                                                NaN
# AD126L00J-Q11                                                NaN
#
#                     tracking_information.metrigo_impression_urls  \
# sku
# NI116D04L-Q11  [https://ccp-et.metrigo.zalan.do/event/sbv?z=9...
# NI114D0B9-Q14  [https://ccp-et.metrigo.zalan.do/event/sbv?z=9...
# TO113I00G-K11  [https://ccp-et.metrigo.zalan.do/event/sbv?z=9...
# AD116D007-A11                                                NaN
# AD126L00J-Q11                                                NaN
#
#               tracking_information.source  \
# sku
# NI116D04L-Q11                         ccp
# NI114D0B9-Q14                         ccp
# TO113I00G-K11                         ccp
# AD116D007-A11                         NaN
# AD126L00J-Q11                         NaN
#
#                                                          url_key
# sku
# NI116D04L-Q11  nike-sportswear-court-borough-mid-boot-winteri...
# NI114D0B9-Q14  nike-sportswear-air-max-200-baskets-basses-ni1...
# TO113I00G-K11         tommy-hilfiger-bottines-blue-to113i00g-k11
# AD116D007-A11  adidas-originals-stan-smith-baskets-basses-bla...
# AD126L00J-Q11  adidas-originals-jacket-veste-dhiver-blackwhit...
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
df.brand_name.value_counts().index[0]
# Out:
# 'Name it'

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
def text_to_float(df,col):
    df[col] = df[col].str.extract('(\d*,\d*)')
    df[col] =  [x.replace(',', '.') for x in df[col]]
    df[col] = df[col].astype(float)
    return df[col]

# %%
df['price.promotional'] = text_to_float(df,'price.promotional')
df['price.original'] = text_to_float(df,'price.original')

# %%
df['discount_amount']=df['price.original']-df['price.promotional']
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name'])['discount_amount'].sum()

# %%
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'Naturino'

# %% [markdown]
# #### Display the brands without discount at all

# %%
total_disc[total_disc==0]
# Out:
# Series([], Name: discount_amount, dtype: float64)
