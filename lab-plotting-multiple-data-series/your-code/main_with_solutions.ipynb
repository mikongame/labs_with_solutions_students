# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Plotting-Multiple-Data-Series" data-toc-modified-id="Plotting-Multiple-Data-Series-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Plotting Multiple Data Series</a></span><ul class="toc-item"><li><span><a href="#1.-Create-a-bar-chart-with-bars-for-total-Retail-Sales,-Retail-Transfers,-and-Warehouse-Sales-by-Item-Type." data-toc-modified-id="1.-Create-a-bar-chart-with-bars-for-total-Retail-Sales,-Retail-Transfers,-and-Warehouse-Sales-by-Item-Type.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.</a></span></li><li><span><a href="#2.-Create-a-horizontal-bar-chart-showing-sales-mix-for-the-top-10-suppliers-with-the-most-total-sales." data-toc-modified-id="2.-Create-a-horizontal-bar-chart-showing-sales-mix-for-the-top-10-suppliers-with-the-most-total-sales.-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.</a></span></li><li><span><a href="#3.-Create-a-multi-line-chart-that-shows-average-Retail-Sales,-Retail-Transfers,-and-Warehouse-Sales-per-month-over-time." data-toc-modified-id="3.-Create-a-multi-line-chart-that-shows-average-Retail-Sales,-Retail-Transfers,-and-Warehouse-Sales-per-month-over-time.-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.</a></span></li><li><span><a href="#4.-Plot-the-same-information-as-above-but-as-a-bar-chart." data-toc-modified-id="4.-Plot-the-same-information-as-above-but-as-a-bar-chart.-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>4. Plot the same information as above but as a bar chart.</a></span></li><li><span><a href="#5.-Create-a-multi-line-chart-that-shows-Retail-Sales-summed-by-Item-Type-over-time-(Year-&amp;-Month)." data-toc-modified-id="5.-Create-a-multi-line-chart-that-shows-Retail-Sales-summed-by-Item-Type-over-time-(Year-&amp;-Month).-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year &amp; Month).</a></span></li><li><span><a href="#6.-Plot-the-same-information-as-above-but-as-a-bar-chart." data-toc-modified-id="6.-Plot-the-same-information-as-above-but-as-a-bar-chart.-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>6. Plot the same information as above but as a bar chart.</a></span></li><li><span><a href="#7.-Create-a-scatter-plot-showing-the-relationship-between-Retail-Sales-(x-axis)-and-Retail-Transfers-(y-axis)-with-the-plot-points-color-coded-according-to-their-Item-Type." data-toc-modified-id="7.-Create-a-scatter-plot-showing-the-relationship-between-Retail-Sales-(x-axis)-and-Retail-Transfers-(y-axis)-with-the-plot-points-color-coded-according-to-their-Item-Type.-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.</a></span></li><li><span><a href="#8.-Create-a-scatter-matrix-using-all-the-numeric-fields-in-the-data-set-with-the-plot-points-color-coded-by-Item-Type." data-toc-modified-id="8.-Create-a-scatter-matrix-using-all-the-numeric-fields-in-the-data-set-with-the-plot-points-color-coded-by-Item-Type.-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('data/liquor_store_sales.csv')
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
# Transform the data
totals = data.groupby('ItemType')[['RetailSales', 'RetailTransfers', 'WarehouseSales']].sum()
totals
# Out:
#               RetailSales  RetailTransfers  WarehouseSales
# ItemType
# BEER            209763.11        234924.44      2437617.32
# DUNNAGE              0.00             0.00       -45331.00
# KEGS                 0.00             0.00        43558.00
# LIQUOR          309847.85        334176.41        33173.32
# NON-ALCOHOL       8109.97          9058.37         8656.72
# REF                281.34           171.92        -6754.00
# STR_SUPPLIES       995.98          3594.70            0.00
# WINE            313400.42        340710.51       433009.47

# %%
totals.plot.bar(figsize=(15,10))
plt.title('Total Retail Sales, Retail Transfers and Warehouse Sales by Item Type', fontweight=700)
plt.ylabel('Total')
plt.show()

# %%
# Plot
totals.plot(kind='bar', figsize=(14,8))
plt.title('Total Retail Sales, Retail Transfers and Warehouse Sales by Item Type', fontweight=700)
plt.ylabel('Total')
plt.show()

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
# Transform the data
supplier_sales = data.groupby('Supplier')[['RetailSales', 'RetailTransfers', 'WarehouseSales']].sum()
supplier_sales['Total'] = supplier_sales.sum(axis=1)
top10_suppliers = supplier_sales.sort_values(by='Total', ascending=False).head(10)
top10_suppliers.drop('Total', axis=1, inplace=True)

# Plot
top10_suppliers.plot(kind='barh', figsize=(14,8))
plt.title('Sales by Top 10 Suppliers', fontweight=700)
plt.xlabel('Total')
plt.ylabel('Supplier')
plt.show()

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
# Transform the data
avg_sales = data.groupby(['Year', 'Month']).mean()
avg_sales.head()
# Out:
#             RetailSales  RetailTransfers  WarehouseSales
# Year Month
# 2017 4         0.000000        15.707503        0.000000
#      5         7.038838         7.421817       27.310548
#      6         7.143914         6.950396       27.839069
#      8         6.409991         6.584726       28.122641
#      9         6.757254         6.419721       22.817909

# %%
avg_sales.plot.bar()

# %%
# Plot
avg_sales.plot(figsize=(14,8))
plt.title('Average Sales Over Time', fontweight=700)
plt.xlabel('Date')
plt.ylabel('Average Sales')

xticks = [f"{str(index[1])}\n{str(index[0])}" for index in data.groupby(['Year', 'Month']).groups.keys()]
plt.xticks(range(len(xticks)), xticks)
plt.show()

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
# Plot
avg_sales.plot(kind='bar', figsize=(14,8))
plt.title('Average Sales Over Time', fontweight=700)
plt.xlabel('Date')
plt.ylabel('Average Sales')
plt.xticks(range(len(xticks)), xticks, rotation=0)
plt.show()

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
# Transform the data
retail_item = pd.pivot_table(data, 
                             columns='ItemType', 
                             values='RetailSales',
                             index=['Year', 'Month'],
                             aggfunc=sum)
xticks = [f"{str(index[1])}\n{str(index[0])}" for index in data.groupby(['Year', 'Month']).groups.keys()]

# Plot
retail_item.plot(figsize=(14,8))
plt.title('Total Retail Sales Per Item Over Time', fontweight=700)
plt.xlabel('Date')
plt.ylabel('Total Retail Sales')
plt.xticks(range(len(xticks)), xticks, rotation=0)
plt.show()

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
# Plot
retail_item.plot(kind='bar', figsize=(14,8))
plt.title('Total Retail Sales Per Item Over Time', fontweight=700)
plt.xlabel('Date')
plt.ylabel('Total Retail Sales')
plt.xticks(range(len(xticks)), xticks, rotation=0)
plt.show()

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
# Plot
scatter = sns.lmplot('RetailSales', 'RetailTransfers', data, hue='ItemType', fit_reg=False)
scatter.fig.set_figwidth(10)
scatter.fig.set_figheight(5)
plt.title('Retail Transfers vs Retail Sales', fontweight=700)
plt.show()

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
sns.pairplot(data, hue='ItemType')
plt.show()
