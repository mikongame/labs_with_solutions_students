# %%
from itertools import product,  combinations
  
# initialize N  
N = 2

lista = ['uno', 'dos', 'tres']
es = [ele for ele in product(lista, repeat = 2)]

# %%
es
# Out:
# [('uno', 'uno'),
#  ('uno', 'dos'),
#  ('uno', 'tres'),
#  ('dos', 'uno'),
#  ('dos', 'dos'),
#  ('dos', 'tres'),
#  ('tres', 'uno'),
#  ('tres', 'dos'),
#  ('tres', 'tres')]

# %%
import itertools
lista = ['uno', 'dos', 'tres']
print(list(itertools.combinations(lista, 2)))
# Out:
# [('uno', 'dos'), ('uno', 'tres'), ('dos', 'tres')]

# %%
np.linspace(0,2 * np.pi,12)
# Out:
# array([0.        , 0.57119866, 1.14239733, 1.71359599, 2.28479466,
#        2.85599332, 3.42719199, 3.99839065, 4.56958931, 5.14078798,
#        5.71198664, 6.28318531])

# %%
import numpy as np
import seaborn as sbs
import matplotlib.pyplot as plt

r = np.arange(0, 3.0, 0.01)
theta = 2 * np.pi * r

ax = plt.subplot(111, polar=True)
ax.plot(theta, r, color='r', linewidth=3)
ax.set_rmax(2.0)
ax.grid(True)


import calendar
ax.set_xticks(np.linspace(0,2 * np.pi,12))
ax.set_xticklabels([i for i in calendar.month_name][1:])
ax.set_facecolor('blue')
ax.set_title("A line plot on a polar axis", va='bottom')

plt.show()

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.PolarAxesSubplot

# %%
meses = [i for i in calendar.month_name][1:]
# Out:
# ['January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August',
#  'September',
#  'October',
#  'November',
#  'December']
